# %% [markdown]
# <a href="https://colab.research.google.com/github/nytakesobi/Kalokhina_pract3/blob/main/pract3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4e95df4d-6507-4e31-9560-2f5b20f77a91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e95df4d-6507-4e31-9560-2f5b20f77a91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('shopping_trends.csv')
print(df)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
import matplotlib as plt

# %% [markdown]
# Гістограма віку (age): Побудуйте гістограму віку клієнтів, використовуючи Seaborn.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
sns.countplot(data=df, x='Age', palette='viridis')
plt.xlabel('Age')
plt.ylabel('Number of Customers')
plt.title('Number of Customers by their Age')
# Out:
# Text(0.5, 1.0, 'Number of Customers by their Age')

# %% [markdown]
# Порівняння розподілу покупок за статтею (item_purchased):
#
# Створіть стовпчасту діаграму або графік розподілу, щоб порівняти, які товари покупають клієнти найчастіше.

# %%
plt.figure(figsize=(10, 10))
sns.countplot(data=df, x='Item Purchased', palette='pastel')
plt.xlabel('AItemge')
plt.ylabel('Number of Customers')
plt.title('Number of Customers by purchase')
# Out:
# Text(0.5, 1.0, 'Number of Customers by purchase')

# %% [markdown]
# Графік розподілу оцінок товарів (review_rating): Побудуйте графік розподілу оцінок товарів для оцінки якості.

# %%
plt.figure(figsize=(10, 10))
sns.countplot(data=df, x='Review Rating', palette='husl')
plt.xlabel('Rating')
plt.ylabel('Number of Customers')
plt.title('Number of Customers by their rating of purchase')

# %% [markdown]
# Категоріальна діаграма для статі (gender): Створіть категоріальну діаграму, щоб відобразити розподіл покупок за статтею.

# %%
plt.figure(figsize=(8, 8))
gender_counts = df['Gender'].value_counts()

plt.figure(figsize=(6, 6))
sns.set_palette("Set3")
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Customer Gender Distribution')
plt.show()

# %% [markdown]
# Залежність між рейтингом і сумою покупок (review_rating і purchase_amount):
#
# Вивчіть, чи існує зв'язок між рейтингом товару і сумою покупок за допомогою scatter plot.

# %%
plt.figure(figsize=(15, 15))
sns.scatterplot(data=df, x='Review Rating', y='Purchase Amount (USD)')
plt.xlabel('Review')
plt.ylabel('Purchase amount')
plt.title('Scatter Plot of reviews vs. amount of goods Purchased')
plt.show()

# %% [markdown]
# Сезонність покупок (season):
#
# Побудуйте стовпчату діаграму, яка відображає, в який сезон клієнти роблять найбільше покупок.

# %%
plt.figure(figsize=(10, 10))
sns.countplot(data=df, x='Season', palette='cubehelix')
plt.xlabel('season')
plt.ylabel('Number of Customers')
plt.title('Number of Customers in each season')
# Out:
# Text(0.5, 1.0, 'Number of Customers in each season')

# %% [markdown]
# Графік розподілу розмірів одягу (size): Створіть графік розподілу розмірів одягу, щоб визначити популярність різних розмірів.

# %%
plt.figure(figsize=(8, 8))
size_counts = df['Size'].value_counts()
sns.set_palette("hls")
plt.pie(size_counts, labels=size_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Customer Gender Distribution')
plt.show()

# %% [markdown]
# Кількість покупок відносно типу оплати (payment_method): Порівняйте, скільки покупок робиться за різними методами оплати за допомогою стовпчатої діаграми.

# %%
plt.figure(figsize=(10, 10))
sns.countplot(data=df, x='Payment Method', palette='icefire')
plt.xlabel('paymeent method')
plt.ylabel('Number of Customers')
plt.title('Number of Customers vs their paying methods')
# Out:
# Text(0.5, 1.0, 'Number of Customers vs their paying methods')

# %% [markdown]
# Залежність між кількістю попередніх покупок (previous_purchases) і сумою поточної покупки (purchase_amount): Створіть scatter plot для визначення, чи існує зв'язок між кількістю попередніх покупок та сумою поточної покупки

# %%
plt.figure(figsize=(15, 15))
sns.scatterplot(data=df, x='Previous Purchases', y='Purchase Amount (USD)')
plt.xlabel('prev purchase')
plt.ylabel('Purchase amount')
plt.title('Scatter Plot of reviews vs. amount of goods Purchased')
plt.show()

# %% [markdown]
# Побудуйте графік поверхні (3D surface plot) для візуалізації залежності між трьома числовими змінними з використанням бібліотеки Seaborn.
#
# Налаштуйте відображення графіка, включаючи назву графіку, підписи осей і інші необхідні параметри для кращого розуміння візуалізації.
#
# Додайте кольорову легенду.

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
x = np.linspace(-5, 5, 20)
y = np.linspace(-5, 5, 20)
X, Y = np.meshgrid(x, y)

Z = np.sin(np.sqrt(X**2 + Y**2))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

surface = ax.plot_surface(X, Y, Z, cmap='icefire')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

fig.colorbar(surface)

ax.set_title('3D Plot of z = sin(sqrt(x^2 + y^2))')

plt.show()

# %%
import numpy as np
from pandas import DataFrame
import seaborn as sns
# %matplotlib inline

Index= ['aaa', 'bbb', 'ccc', 'ddd', 'eee']
Cols = ['A', 'B', 'C', 'D']
matr = [[1,2,3,4],[1,2,3,3],[3,3,4,4,],[1,1,2,2,],[3,3,4,4]]
df = DataFrame(matr, index=Index, columns=Cols)

sns.heatmap(df, annot=True)
# Out:
# <Axes: >
